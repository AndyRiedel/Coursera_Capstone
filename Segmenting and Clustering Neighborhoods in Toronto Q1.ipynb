# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import folium
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# Below we get the HTML with requests, and cut all of the HTML around the first table out of the variable.
# We're assuming that the table we want is the first table on the page

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')
#print(soup.prettify())
soup = str(soup)
start = soup.find('<tbody')
end = soup.find('</tbody>')
table = soup[start:end]

# %% [markdown]
# We split the rows of the table text into a list and coerce this into a dataframe.
# We're assuming the table has a header row, and that each table row is denoted by a <tr> tag, as well as each cell in a row being denoted by a <td> tag.

# %%
dataframe = []
table = table[table.find('</th>'):]
table = table[table.find('</tr>')+4:]
append = table.split('<tr>')
dataframe = [i.split('<td>') for i in append]



df = pd.DataFrame(dataframe)

# %% [markdown]
# We need to clean up the data frame a little. We're just finding/replacing and slicing out a bunch of the HTML surrounding dataframe values

# %%
df.rename(columns={1: 'PostalCode', 2:'Borough', 3:'Neighborhood'}, inplace = True)
df.drop(columns=0, inplace=True)

df['PostalCode'] = df['PostalCode'].str[:3]

df.drop([0], inplace = True)

for i, j in df.iterrows():
    j.Borough = j.Borough.replace('</a>', '')
    j.Borough = j.Borough.replace('</td>', '')
    j.Borough = j.Borough.replace('\n', '')
    if j.Borough.find('<a') > -1:
        j.Borough = j.Borough[j.Borough.find('>')+1:]
    j.Neighborhood = j.Neighborhood.replace('</td></tr>', '')
    j.Neighborhood = j.Neighborhood.replace('</a>', '')
    j.Neighborhood = j.Neighborhood.replace('\n', '')
    if j.Neighborhood.find('<a') > -1:
        j.Neighborhood = j.Neighborhood[j.Neighborhood.find('>')+1:]
    
df = df.loc[df['Borough'] != 'Not assigned']
df.reset_index()
# Out:
#      index PostalCode           Borough  \
# 0        3        M3A        North York
# 1        4        M4A        North York
# 2        5        M5A  Downtown Toronto
# 3        6        M5A  Downtown Toronto
# 4        7        M6A        North York
# 5        8        M6A        North York
# 6        9        M7A      Queen's Park
# 7       11        M9A         Etobicoke
# 8       12        M1B       Scarborough
# 9       13        M1B       Scarborough
# 10      15        M3B        North York
# 11      16        M4B         East York
# 12      17        M4B         East York
# 13      18        M5B  Downtown Toronto
# 14      19        M5B  Downtown Toronto
# 15      20        M6B        North York
# 16      23        M9B         Etobicoke
# 17      24        M9B         Etobicoke
# 18      25        M9B         Etobicoke
# 19      26        M9B         Etobicoke
# 20      27        M9B         Etobicoke
# 21      28        M1C       Scarborough
# 22      29        M1C       Scarborough
# 23      30        M1C       Scarborough
# 24      32        M3C        North York
# 25      33        M3C        North York
# 26      34        M4C         East York
# 27      35        M5C  Downtown Toronto
# 28      36        M6C              York
# 29      39        M9C         Etobicoke
# ..     ...        ...               ...
# 182    237        M1W       Scarborough
# 183    238        M1W       Scarborough
# 184    241        M4W  Downtown Toronto
# 185    242        M5W  Downtown Toronto
# 186    245        M8W         Etobicoke
# 187    246        M8W         Etobicoke
# 188    247        M9W         Etobicoke
# 189    248        M1X       Scarborough
# 190    251        M4X  Downtown Toronto
# 191    252        M4X  Downtown Toronto
# 192    253        M5X  Downtown Toronto
# 193    254        M5X  Downtown Toronto
# 194    257        M8X         Etobicoke
# 195    258        M8X         Etobicoke
# 196    259        M8X         Etobicoke
# 197    264        M4Y  Downtown Toronto
# 198    267        M7Y      East Toronto
# 199    268        M8Y         Etobicoke
# 200    269        M8Y         Etobicoke
# 201    270        M8Y         Etobicoke
# 202    271        M8Y         Etobicoke
# 203    272        M8Y         Etobicoke
# 204    273        M8Y         Etobicoke
# 205    274        M8Y         Etobicoke
# 206    275        M8Y         Etobicoke
# 207    284        M8Z         Etobicoke
# 208    285        M8Z         Etobicoke
# 209    286        M8Z         Etobicoke
# 210    287        M8Z         Etobicoke
# 211    288        M8Z         Etobicoke
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                        Harbourfront
# 3                                         Regent Park
# 4                                    Lawrence Heights
# 5                                      Lawrence Manor
# 6                                        Not assigned
# 7                                    Islington Avenue
# 8                                               Rouge
# 9                                             Malvern
# 10                                    Don Mills North
# 11                                   Woodbine Gardens
# 12                                      Parkview Hill
# 13                                            Ryerson
# 14                                    Garden District
# 15                                          Glencairn
# 16                                         Cloverdale
# 17                                          Islington
# 18                                       Martin Grove
# 19                                   Princess Gardens
# 20                                    West Deane Park
# 21                                     Highland Creek
# 22                                         Rouge Hill
# 23                                         Port Union
# 24                                    Flemingdon Park
# 25                                    Don Mills South
# 26                                   Woodbine Heights
# 27                                     St. James Town
# 28                                 Humewood-Cedarvale
# 29                                  Bloordale Gardens
# ..                                                ...
# 182                                   L'Amoreaux West
# 183                                      Steeles West
# 184                                          Rosedale
# 185                   Stn A PO Boxes 25 The Esplanade
# 186                                         Alderwood
# 187                                       Long Branch
# 188                                         Northwest
# 189                                       Upper Rouge
# 190                                       Cabbagetown
# 191                                    St. James Town
# 192                              First Canadian Place
# 193                                  Underground city
# 194                                      The Kingsway
# 195                                   Montgomery Road
# 196                                    Old Mill North
# 197                              Church and Wellesley
# 198  Business reply mail Processing Centre969 Eastern
# 199                                        Humber Bay
# 200                                  King's Mill Park
# 201                          Kingsway Park South East
# 202                                         Mimico NE
# 203                                    Old Mill South
# 204                                The Queensway East
# 205                             Royal York South East
# 206                                          Sunnylea
# 207                          Kingsway Park South West
# 208                                         Mimico NW
# 209                                The Queensway West
# 210                             Royal York South West
# 211                                    South of Bloor
#
# [212 rows x 4 columns]

# %% [markdown]
# To consolidate duplicates, we'll group by postal code and borough, and aggregate the neighborhood values.

# %%
df_grouped = pd.DataFrame(df.groupby(['PostalCode', 'Borough'])['Neighborhood'].aggregate(lambda x: ', '.join(x)))
df_grouped.reset_index(inplace=True)
print(df_grouped.shape)
df_grouped[:50]
# Out:
# (103, 3)
#    PostalCode          Borough  \
# 0         M1B      Scarborough
# 1         M1C      Scarborough
# 2         M1E      Scarborough
# 3         M1G      Scarborough
# 4         M1H      Scarborough
# 5         M1J      Scarborough
# 6         M1K      Scarborough
# 7         M1L      Scarborough
# 8         M1M      Scarborough
# 9         M1N      Scarborough
# 10        M1P      Scarborough
# 11        M1R      Scarborough
# 12        M1S      Scarborough
# 13        M1T      Scarborough
# 14        M1V      Scarborough
# 15        M1W      Scarborough
# 16        M1X      Scarborough
# 17        M2H       North York
# 18        M2J       North York
# 19        M2K       North York
# 20        M2L       North York
# 21        M2M       North York
# 22        M2N       North York
# 23        M2P       North York
# 24        M2R       North York
# 25        M3A       North York
# 26        M3B       North York
# 27        M3C       North York
# 28        M3H       North York
# 29        M3J       North York
# 30        M3K       North York
# 31        M3L       North York
# 32        M3M       North York
# 33        M3N       North York
# 34        M4A       North York
# 35        M4B        East York
# 36        M4C        East York
# 37        M4E     East Toronto
# 38        M4G        East York
# 39        M4H        East York
# 40        M4J        East York
# 41        M4K     East Toronto
# 42        M4L     East Toronto
# 43        M4M     East Toronto
# 44        M4N  Central Toronto
# 45        M4P  Central Toronto
# 46        M4R  Central Toronto
# 47        M4S  Central Toronto
# 48        M4T  Central Toronto
# 49        M4V  Central Toronto
#
#                                          Neighborhood
# 0                                      Rouge, Malvern
# 1              Highland Creek, Rouge Hill, Port Union
# 2                   Guildwood, Morningside, West Hill
# 3                                              Woburn
# 4                                           Cedarbrae
# 5                                 Scarborough Village
# 6         East Birchmount Park, Ionview, Kennedy Park
# 7                     Clairlea, Golden Mile, Oakridge
# 8     Cliffcrest, Cliffside, Scarborough Village West
# 9                         Birch Cliff, Cliffside West
# 10  Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                  Maryvale, Wexford
# 12                                          Agincourt
# 13            Clarks Corners, Sullivan, Tam O'Shanter
# 14  Agincourt North, L'Amoreaux East, Milliken, St...
# 15                      L'Amoreaux West, Steeles West
# 16                                        Upper Rouge
# 17                                  Hillcrest Village
# 18                       Fairview, Henry Farm, Oriole
# 19                                    Bayview Village
# 20                           Silver Hills, York Mills
# 21                            Newtonbrook, Willowdale
# 22                                   Willowdale South
# 23                                    York Mills West
# 24                                    Willowdale West
# 25                                          Parkwoods
# 26                                    Don Mills North
# 27                   Flemingdon Park, Don Mills South
# 28    Bathurst Manor, Downsview North, Wilson Heights
# 29                    Northwood Park, York University
# 30                        CFB Toronto, Downsview East
# 31                                     Downsview West
# 32                                  Downsview Central
# 33                                Downsview Northwest
# 34                                   Victoria Village
# 35                    Woodbine Gardens, Parkview Hill
# 36                                   Woodbine Heights
# 37                                        The Beaches
# 38                                            Leaside
# 39                                   Thorncliffe Park
# 40                                       East Toronto
# 41                       The Danforth West, Riverdale
# 42                     The Beaches West, India Bazaar
# 43                                    Studio District
# 44                                      Lawrence Park
# 45                                   Davisville North
# 46                                 North Toronto West
# 47                                         Davisville
# 48                        Moore Park, Summerhill East
# 49  Deer Park, Forest Hill SE, Rathnelly, South Hi...

# %%
lat_lng_csv = requests.get('http://cocl.us/Geospatial_data').text
lat_lng = lat_lng_csv.split('\r')
lat_lng = [i.split(',') for i in lat_lng]
postal_codes = pd.DataFrame(lat_lng)
postal_codes.rename(columns={0:'PostalCode', 1:'Latitude', 2:'Longitude'}, inplace = True)
postal_codes.drop([0], inplace=True)
for i, j in postal_codes.iterrows():
    j.PostalCode = j.PostalCode[1:]

df_grouped = df_grouped.merge(postal_codes, how = 'left', on = 'PostalCode')
df_grouped.Latitude = df_grouped.Latitude.astype('float')
df_grouped.Longitude = df_grouped.Longitude.astype('float')
df_grouped[:5]
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
import folium
toronto_map = folium.Map(location=[df_grouped.Latitude.mean(), df_grouped.Longitude.mean()], zoom_start = 12)

for i, j in df_grouped.iterrows():
    folium.Marker(location = [j.Latitude, j.Longitude]).add_to(toronto_map)

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
clientid = #your Client ID
secret = #your ID Secret
version = '20180605'

# %%
def get_venues(lat, lng, radius, limit):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{},&v={}&radius = {}&limit = {}'.format(
        clientid,
        secret,
        lat,
        lng,
        version,
        radius,
        limit)
    
    results = requests.get(url).json()
    items = results['response']['groups'][0]['items']
    results_df = json_normalize(items)
    return results_df[['venue.id', 'venue.location.lat', 'venue.location.lng', 'venue.categories']]

# %%
cat_url = 'https://api.foursquare.com/v2/venues/categories?client_id={}&client_secret={}&v={}'.format(
    clientid,
    secret,
    version)
venue_categories = requests.get(cat_url).json()
cat_df = pd.DataFrame(columns=['Group', 'Name', 'Detail'])
for i in venue_categories['response']['categories']:
    group = i['name']
    for j in i['categories']:
        name = j['name']
        for k in j['categories']:
            detail = k['name']
            entry = {'Group':group, 'Name':name, 'Detail': detail}
            cat_df = cat_df.append(entry, ignore_index = True)

# %%
radius = 1000 #we'll travel up to 1km for our daily activities?
limit = 500 #let's only retrieve 500 results
df2 = None
df2 = pd.DataFrame(columns = ['PostalCode','Borough', 'Neighborhood','Latitude', 'Longitude',
                                 'venue.location.lat', 'venue.location.lng','venue.categories'])
for i, j in df_grouped.iterrows():
        results = get_venues(j.Latitude, j.Longitude, radius, limit)
        results['venue.categories'] = [i[0].get('name') for i in results['venue.categories']]
        results['PostalCode'] = j.PostalCode
        results['Borough'] = j.Borough
        results['Neighborhood'] = j.Neighborhood
        results['Latitude'] = j.Latitude
        results['Longitude'] = j.Longitude
        df2 = df2.append(results, ignore_index = True)

# %%
df2 = df2.merge(cat_df, how = 'left', left_on = 'venue.categories', right_on = 'Name')
df2['venue_type'] = df2['Group']
df2.drop(columns=['Detail', 'Group', 'Name'], inplace = True)


df2 = df2.merge(cat_df, how = 'left', left_on = 'venue.categories',
               right_on = 'Detail')
for i, j in df2.iterrows():
    if pd.isnull(j.venue_type) == True:
        df2.set_value(i, 'venue_type', j.Group)
df2.drop(columns=['Group','Detail', 'Name'], inplace = True)


for i, j in df2.iterrows():
    if pd.isnull(j.venue_type) == True:
        df2.set_value(i, 'venue_type', 'Other')
# Out:
# C:\Users\Das_S\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Das_S\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()

# %%
#df3 = df2.pivot_table(index = ['Neighborhood', 'venue.categories'], aggfunc = 'size')
#df3 = df3.reset_index()
#df3 = df3.groupby('Neighborhood').head()
df3.sort_values(by=['Neighborhood', 0], ascending = [True, False], inplace = True)
onehot = pd.get_dummies(df3[['venue.categories']])
onehot['Neighborhood'] = df3['Neighborhood']
onehot = onehot.groupby('Neighborhood').mean().reset_index()

toronto_cluster_data = onehot.drop(columns=['Neighborhood'])
clusters = 5
for i in onehot['Neighborhood']:
    print(i)
    temp = onehot[onehot['Neighborhood'] == i].T.reset_index()
    temp.columns = ['venue', 'freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq':2})
    
toronto_grouped_clustering = onehot.drop(columns=['Neighborhood'])
kmeans = KMeans(n_clusters = clusters, random_state = 123).fit(toronto_grouped_clustering)

toronto_merged = df_grouped
toronto_merged['Cluster'] = kmeans.labels_

map_clusters = folium.Map(location = [df_grouped.Latitude.mean(), df_grouped.Longitude.mean()], zoom_start = 11)

x = np.arange(clusters)
y = [i+x+(i*x)**2 for i in range(clusters)]
colors_array = cm.rainbow(np.linspace(0,1,len(y)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
marker_colors =[]

for latitude, longitude, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Cluster']):
    label = folium.Popup(str(cluster), parse_html=True)
    folium.CircleMarker([latitude, longitude], radius = 5, popup = label,
                        color = rainbow[cluster-1], fill = True, fill_color = rainbow[cluster-1],
                       fill_opacity = 0.9).add_to(map_clusters)
# Out:
# Adelaide, King, Richmond
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1                 venue.categories_Café   0.2
# 2     venue.categories_Asian Restaurant   0.2
# 3       venue.categories_Breakfast Spot   0.2
# 4                  venue.categories_Bar   0.2
#
#
# Agincourt
#                                    venue  freq
# 0                venue.categories_Bakery   0.2
# 1   venue.categories_Arts & Crafts Store   0.2
# 2      venue.categories_Asian Restaurant   0.2
# 3  venue.categories_Cantonese Restaurant   0.2
# 4        venue.categories_Breakfast Spot   0.2
#
#
# Agincourt North, L'Amoreaux East, Milliken, Steeles East
#                                    venue  freq
# 0    venue.categories_Chinese Restaurant   0.2
# 1       venue.categories_Bubble Tea Shop   0.2
# 2      venue.categories_Asian Restaurant   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Albion Gardens, Beaumond Heights, Humbergate, Jamestown, Mount Olive, Silverstone, South Steeles, Thistletown
#                                    venue  freq
# 0    venue.categories_Chinese Restaurant   0.2
# 1                  venue.categories_Café   0.2
# 2      venue.categories_Asian Restaurant   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Alderwood, Long Branch
#                            venue  freq
# 0     venue.categories_Bookstore   0.2
# 1   venue.categories_Coffee Shop   0.2
# 2  venue.categories_Burger Joint   0.2
# 3  venue.categories_Climbing Gym   0.2
# 4          venue.categories_Café   0.2
#
#
# Bathurst Manor, Downsview North, Wilson Heights
#                                  venue  freq
# 0         venue.categories_Bridal Shop   0.2
# 1                venue.categories_Café   0.2
# 2    venue.categories_Asian Restaurant   0.2
# 3  venue.categories_Athletics & Sports   0.2
# 4          venue.categories_Bagel Shop   0.2
#
#
# Bayview Village
#                                  venue  freq
# 0          venue.categories_Bagel Shop   0.2
# 1     venue.categories_Bubble Tea Shop   0.2
# 2         venue.categories_Coffee Shop   0.2
# 3                venue.categories_Café   0.2
# 4  venue.categories_Chinese Restaurant   0.2
#
#
# Bedford Park, Lawrence Manor East
#                               venue  freq
# 0   venue.categories_Breakfast Spot   0.2
# 1      venue.categories_Bridal Shop   0.2
# 2  venue.categories_Bubble Tea Shop   0.2
# 3           venue.categories_Bakery   0.2
# 4       venue.categories_Bagel Shop   0.2
#
#
# Berczy Park
#                                  venue  freq
# 0              venue.categories_Bistro   0.2
# 1  venue.categories_Belgian Restaurant   0.2
# 2            venue.categories_Beer Bar   0.2
# 3  venue.categories_Basketball Stadium   0.2
# 4              venue.categories_Bakery   0.2
#
#
# Birch Cliff, Cliffside West
#                              venue  freq
# 0      venue.categories_Bagel Shop   0.2
# 1    venue.categories_Burger Joint   0.2
# 2           venue.categories_Beach   0.2
# 3          venue.categories_Bakery   0.2
# 4  venue.categories_Breakfast Spot   0.2
#
#
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
#                                   venue  freq
# 0            venue.categories_Bookstore   0.2
# 1  venue.categories_American Restaurant   0.2
# 2  venue.categories_Arts & Crafts Store   0.2
# 3         venue.categories_Climbing Gym   0.2
# 4                 venue.categories_Café   0.2
#
#
# Brockton, Exhibition Place, Parkdale Village
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1            venue.categories_BBQ Joint   0.2
# 2  venue.categories_American Restaurant   0.2
# 3                  venue.categories_Bar   0.2
# 4  venue.categories_Arts & Crafts Store   0.2
#
#
# Business reply mail Processing Centre969 Eastern
#                                venue  freq
# 0            venue.categories_Bakery   0.2
# 1             venue.categories_Beach   0.2
# 2  venue.categories_Asian Restaurant   0.2
# 3         venue.categories_BBQ Joint   0.2
# 4               venue.categories_Bar   0.2
#
#
# CFB Toronto, Downsview East
#                                   venue  freq
# 0       venue.categories_Chocolate Shop   0.2
# 1               venue.categories_Bakery   0.2
# 2            venue.categories_Bookstore   0.2
# 3  venue.categories_American Restaurant   0.2
# 4   venue.categories_Athletics & Sports   0.2
#
#
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
#                                venue  freq
# 0           venue.categories_Brewery   0.2
# 1           venue.categories_Airport   0.2
# 2    venue.categories_Airport Lounge   0.2
# 3              venue.categories_Café   0.2
# 4  venue.categories_Baseball Stadium   0.2
#
#
# Cabbagetown, St. James Town
#                                    venue  freq
# 0  venue.categories_Caribbean Restaurant   0.2
# 1         venue.categories_Deli / Bodega   0.2
# 2               venue.categories_Butcher   0.2
# 3                  venue.categories_Café   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Caledonia-Fairbanks
#                                    venue  freq
# 0                venue.categories_Bakery   0.2
# 1  venue.categories_Brazilian Restaurant   0.2
# 2             venue.categories_Bike Shop   0.2
# 3                   venue.categories_Bar   0.2
# 4             venue.categories_BBQ Joint   0.2
#
#
# Canada Post Gateway Processing Centre
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1         venue.categories_Burger Joint   0.2
# 2        venue.categories_Burrito Place   0.2
# 3     venue.categories_Asian Restaurant   0.2
# 4       venue.categories_Breakfast Spot   0.2
#
#
# Cedarbrae
#                                    venue  freq
# 0        venue.categories_Breakfast Spot   0.2
# 1  venue.categories_Caribbean Restaurant   0.2
# 2             venue.categories_Bookstore   0.2
# 3          venue.categories_Burger Joint   0.2
# 4    venue.categories_Chinese Restaurant   0.2
#
#
# Central Bay Street
#                                  venue  freq
# 0  venue.categories_Chinese Restaurant   0.2
# 1     venue.categories_Bubble Tea Shop   0.2
# 2          venue.categories_Art Museum   0.2
# 3                venue.categories_Café   0.2
# 4                 venue.categories_Bar   0.2
#
#
# Chinatown, Grange Park, Kensington Market
#                                   venue  freq
# 0         venue.categories_Burger Joint   0.2
# 1             venue.categories_Beer Bar   0.2
# 2  venue.categories_Arts & Crafts Store   0.2
# 3                  venue.categories_Bar   0.2
# 4               venue.categories_Bakery   0.2
#
#
# Christie
#                            venue  freq
# 0  venue.categories_Cupcake Shop   0.2
# 1   venue.categories_Comedy Club   0.2
# 2   venue.categories_Coffee Shop   0.2
# 3  venue.categories_Cocktail Bar   0.2
# 4          venue.categories_Café   0.2
#
#
# Church and Wellesley
#                               venue  freq
# 0   venue.categories_Adult Boutique   0.2
# 1   venue.categories_Breakfast Spot   0.2
# 2        venue.categories_Bookstore   0.2
# 3  venue.categories_Bubble Tea Shop   0.2
# 4              venue.categories_Bar   0.2
#
#
# Clairlea, Golden Mile, Oakridge
#                              venue  freq
# 0  venue.categories_Breakfast Spot   0.2
# 1         venue.categories_Brewery   0.2
# 2    venue.categories_Burger Joint   0.2
# 3            venue.categories_Café   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Clarks Corners, Sullivan, Tam O'Shanter
#                                   venue  freq
# 0       venue.categories_Breakfast Spot   0.2
# 1               venue.categories_Bakery   0.2
# 2            venue.categories_Bookstore   0.2
# 3  venue.categories_Arts & Crafts Store   0.2
# 4     venue.categories_Asian Restaurant   0.2
#
#
# Cliffcrest, Cliffside, Scarborough Village West
#                                venue  freq
# 0            venue.categories_Bistro   0.2
# 1      venue.categories_Burger Joint   0.2
# 2             venue.categories_Beach   0.2
# 3  venue.categories_Asian Restaurant   0.2
# 4    venue.categories_Breakfast Spot   0.2
#
#
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1         venue.categories_Burger Joint   0.2
# 2          venue.categories_Coffee Shop   0.2
# 3                 venue.categories_Café   0.2
# 4               venue.categories_Bakery   0.2
#
#
# Commerce Court, Victoria Hotel
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1  venue.categories_American Restaurant   0.2
# 2          venue.categories_Art Gallery   0.2
# 3          venue.categories_Coffee Shop   0.2
# 4                 venue.categories_Café   0.2
#
#
# Davisville
#                            venue  freq
# 0     venue.categories_Bookstore   0.2
# 1       venue.categories_Brewery   0.2
# 2   venue.categories_Coffee Shop   0.2
# 3  venue.categories_Churrascaria   0.2
# 4          venue.categories_Café   0.2
#
#
# Davisville North
#                              venue  freq
# 0       venue.categories_Bookstore   0.2
# 1            venue.categories_Café   0.2
# 2    venue.categories_Churrascaria   0.2
# 3  venue.categories_Baseball Field   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1  venue.categories_American Restaurant   0.2
# 2                 venue.categories_Café   0.2
# 3   venue.categories_Athletics & Sports   0.2
# 4           venue.categories_Bagel Shop   0.2
#
#
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
#                                    venue  freq
# 0                venue.categories_Bakery   0.2
# 1  venue.categories_Brazilian Restaurant   0.2
# 2             venue.categories_Bike Shop   0.2
# 3                   venue.categories_Bar   0.2
# 4             venue.categories_BBQ Joint   0.2
#
#
# Design Exchange, Toronto Dominion Centre
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1  venue.categories_American Restaurant   0.2
# 2          venue.categories_Art Gallery   0.2
# 3                 venue.categories_Café   0.2
# 4                  venue.categories_Bar   0.2
#
#
# Don Mills North
#                            venue  freq
# 0    venue.categories_Bagel Shop   0.2
# 1  venue.categories_Burger Joint   0.2
# 2          venue.categories_Café   0.2
# 3           venue.categories_Bar   0.2
# 4        venue.categories_Bakery   0.2
#
#
# Dorset Park, Scarborough Town Centre, Wexford Heights
#                                   venue  freq
# 0            venue.categories_Bookstore   0.2
# 1         venue.categories_Burger Joint   0.2
# 2  venue.categories_Arts & Crafts Store   0.2
# 3     venue.categories_Asian Restaurant   0.2
# 4       venue.categories_Breakfast Spot   0.2
#
#
# Dovercourt Village, Dufferin
#                                    venue  freq
# 0        venue.categories_Breakfast Spot   0.2
# 1  venue.categories_Brazilian Restaurant   0.2
# 2              venue.categories_Beer Bar   0.2
# 3                   venue.categories_Bar   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Downsview Central
#                                  venue  freq
# 0            venue.categories_Boutique   0.2
# 1  venue.categories_Athletics & Sports   0.2
# 2       venue.categories_Burrito Place   0.2
# 3              venue.categories_Bakery   0.2
# 4             venue.categories_Brewery   0.2
#
#
# Downsview Northwest
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1         venue.categories_Burger Joint   0.2
# 2          venue.categories_Coffee Shop   0.2
# 3     venue.categories_Asian Restaurant   0.2
# 4                 venue.categories_Café   0.2
#
#
# Downsview West
#                                  venue  freq
# 0            venue.categories_Boutique   0.2
# 1              venue.categories_Bakery   0.2
# 2       venue.categories_Burrito Place   0.2
# 3    venue.categories_Asian Restaurant   0.2
# 4  venue.categories_Athletics & Sports   0.2
#
#
# East Birchmount Park, Ionview, Kennedy Park
#                                  venue  freq
# 0  venue.categories_Chinese Restaurant   0.2
# 1        venue.categories_Burger Joint   0.2
# 2               venue.categories_Beach   0.2
# 3      venue.categories_Clothing Store   0.2
# 4    venue.categories_Asian Restaurant   0.2
#
#
# East Toronto
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1             venue.categories_Beer Bar   0.2
# 2            venue.categories_BBQ Joint   0.2
# 3  venue.categories_American Restaurant   0.2
# 4     venue.categories_Asian Restaurant   0.2
#
#
# Emery, Humberlea
#                                    venue  freq
# 0         venue.categories_Burrito Place   0.2
# 1                  venue.categories_Café   0.2
# 2      venue.categories_Asian Restaurant   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Fairview, Henry Farm, Oriole
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1      venue.categories_Bubble Tea Shop   0.2
# 2         venue.categories_Burger Joint   0.2
# 3               venue.categories_Bakery   0.2
# 4       venue.categories_Breakfast Spot   0.2
#
#
# First Canadian Place, Underground city
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1  venue.categories_American Restaurant   0.2
# 2          venue.categories_Art Gallery   0.2
# 3                 venue.categories_Café   0.2
# 4                  venue.categories_Bar   0.2
#
#
# Flemingdon Park, Don Mills South
#                            venue  freq
# 0     venue.categories_BBQ Joint   0.2
# 1  venue.categories_Burger Joint   0.2
# 2          venue.categories_Café   0.2
# 3           venue.categories_Bar   0.2
# 4        venue.categories_Bakery   0.2
#
#
# Forest Hill North, Forest Hill West
#                              venue  freq
# 0      venue.categories_Bagel Shop   0.2
# 1       venue.categories_Bookstore   0.2
# 2    venue.categories_Burger Joint   0.2
# 3  venue.categories_Baseball Field   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Glencairn
#                                   venue  freq
# 0              venue.categories_Brewery   0.2
# 1               venue.categories_Bakery   0.2
# 2  venue.categories_American Restaurant   0.2
# 3            venue.categories_Bike Shop   0.2
# 4       venue.categories_Breakfast Spot   0.2
#
#
# Guildwood, Morningside, West Hill
#                                  venue  freq
# 0        venue.categories_Burger Joint   0.2
# 1             venue.categories_Butcher   0.2
# 2  venue.categories_Athletics & Sports   0.2
# 3              venue.categories_Bakery   0.2
# 4      venue.categories_Breakfast Spot   0.2
#
#
# Harbord, University of Toronto
#                         venue  freq
# 0  venue.categories_Bookstore   0.2
# 1   venue.categories_Beer Bar   0.2
# 2       venue.categories_Café   0.2
# 3        venue.categories_Bar   0.2
# 4     venue.categories_Bakery   0.2
#
#
# Harbourfront East, Toronto Islands, Union Station
#                                  venue  freq
# 0              venue.categories_Bakery   0.2
# 1              venue.categories_Bistro   0.2
# 2            venue.categories_Aquarium   0.2
# 3         venue.categories_Art Gallery   0.2
# 4  venue.categories_Basketball Stadium   0.2
#
#
# Harbourfront, Regent Park
#                              venue  freq
# 0  venue.categories_Breakfast Spot   0.2
# 1     venue.categories_Coffee Shop   0.2
# 2            venue.categories_Café   0.2
# 3  venue.categories_Chocolate Shop   0.2
# 4          venue.categories_Bakery   0.2
#
#
# High Park, The Junction South
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1         venue.categories_Antique Shop   0.2
# 2                 venue.categories_Café   0.2
# 3  venue.categories_Arts & Crafts Store   0.2
# 4                  venue.categories_Bar   0.2
#
#
# Highland Creek, Rouge Hill, Port Union
#                                  venue  freq
# 0      venue.categories_Breakfast Spot   0.2
# 1              venue.categories_Bakery   0.2
# 2               venue.categories_Beach   0.2
# 3  venue.categories_Athletics & Sports   0.2
# 4           venue.categories_BBQ Joint   0.2
#
#
# Hillcrest Village
#                                venue  freq
# 0        venue.categories_Bagel Shop   0.2
# 1  venue.categories_Asian Restaurant   0.2
# 2            venue.categories_Bakery   0.2
# 3         venue.categories_BBQ Joint   0.2
# 4    venue.categories_Breakfast Spot   0.2
#
#
# Humber Bay Shores, Mimico South, New Toronto
#                             venue  freq
# 0        venue.categories_Brewery   0.2
# 1    venue.categories_Coffee Shop   0.2
# 2  venue.categories_Burrito Place   0.2
# 3           venue.categories_Café   0.2
# 4         venue.categories_Bakery   0.2
#
#
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico NE, Old Mill South, The Queensway East, Royal York South East, Sunnylea
#                              venue  freq
# 0         venue.categories_Brewery   0.2
# 1  venue.categories_Breakfast Spot   0.2
# 2          venue.categories_Bridge   0.2
# 3             venue.categories_Bar   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Humber Summit
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1            venue.categories_Bookstore   0.2
# 2  venue.categories_American Restaurant   0.2
# 3         venue.categories_Burger Joint   0.2
# 4     venue.categories_Asian Restaurant   0.2
#
#
# Humewood-Cedarvale
#                              venue  freq
# 0       venue.categories_BBQ Joint   0.2
# 1      venue.categories_Bagel Shop   0.2
# 2            venue.categories_Café   0.2
# 3          venue.categories_Bakery   0.2
# 4  venue.categories_Breakfast Spot   0.2
#
#
# Islington Avenue
#                              venue  freq
# 0  venue.categories_Breakfast Spot   0.2
# 1     venue.categories_Coffee Shop   0.2
# 2    venue.categories_Burger Joint   0.2
# 3            venue.categories_Café   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
#                                   venue  freq
# 0              venue.categories_Brewery   0.2
# 1               venue.categories_Bakery   0.2
# 2  venue.categories_American Restaurant   0.2
# 3         venue.categories_Burger Joint   0.2
# 4     venue.categories_Asian Restaurant   0.2
#
#
# Kingsway Park South West, Mimico NW, The Queensway West, Royal York South West, South of Bloor
#                                venue  freq
# 0         venue.categories_BBQ Joint   0.2
# 1            venue.categories_Bakery   0.2
# 2  venue.categories_Asian Restaurant   0.2
# 3               venue.categories_Bar   0.2
# 4           venue.categories_Brewery   0.2
#
#
# L'Amoreaux West, Steeles West
#                                    venue  freq
# 0             venue.categories_BBQ Joint   0.2
# 1        venue.categories_Breakfast Spot   0.2
# 2          venue.categories_Burger Joint   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Lawrence Heights, Lawrence Manor
#                                   venue  freq
# 0             venue.categories_Boutique   0.2
# 1               venue.categories_Bakery   0.2
# 2            venue.categories_Bookstore   0.2
# 3  venue.categories_American Restaurant   0.2
# 4   venue.categories_Athletics & Sports   0.2
#
#
# Lawrence Park
#                               venue  freq
# 0        venue.categories_BBQ Joint   0.2
# 1  venue.categories_Bubble Tea Shop   0.2
# 2     venue.categories_Burger Joint   0.2
# 3             venue.categories_Café   0.2
# 4           venue.categories_Bakery   0.2
#
#
# Leaside
#                                 venue  freq
# 0             venue.categories_Bakery   0.2
# 1  venue.categories_Afghan Restaurant   0.2
# 2          venue.categories_BBQ Joint   0.2
# 3    venue.categories_Auto Dealership   0.2
# 4   venue.categories_Asian Restaurant   0.2
#
#
# Little Portugal, Trinity
#                                   venue  freq
# 0             venue.categories_Boutique   0.2
# 1  venue.categories_American Restaurant   0.2
# 2          venue.categories_Art Gallery   0.2
# 3     venue.categories_Asian Restaurant   0.2
# 4                  venue.categories_Bar   0.2
#
#
# Maple Leaf Park, North Park, Upwood Park
#                                  venue  freq
# 0            venue.categories_Boutique   0.2
# 1  venue.categories_Athletics & Sports   0.2
# 2           venue.categories_Bike Shop   0.2
# 3              venue.categories_Bakery   0.2
# 4             venue.categories_Brewery   0.2
#
#
# Maryvale, Wexford
#                                    venue  freq
# 0    venue.categories_Chinese Restaurant   0.2
# 1      venue.categories_Asian Restaurant   0.2
# 2          venue.categories_Burger Joint   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4        venue.categories_Breakfast Spot   0.2
#
#
# Moore Park, Summerhill East
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1  venue.categories_American Restaurant   0.2
# 2                 venue.categories_Café   0.2
# 3   venue.categories_Athletics & Sports   0.2
# 4           venue.categories_Bagel Shop   0.2
#
#
# Newtonbrook, Willowdale
#                                venue  freq
# 0   venue.categories_Bubble Tea Shop   0.2
# 1      venue.categories_Burger Joint   0.2
# 2              venue.categories_Café   0.2
# 3  venue.categories_Asian Restaurant   0.2
# 4   venue.categories_Auto Dealership   0.2
#
#
# North Toronto West
#                              venue  freq
# 0       venue.categories_Bookstore   0.2
# 1            venue.categories_Café   0.2
# 2    venue.categories_Churrascaria   0.2
# 3  venue.categories_Baseball Field   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Northwest
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1  venue.categories_American Restaurant   0.2
# 2         venue.categories_Burger Joint   0.2
# 3     venue.categories_Asian Restaurant   0.2
# 4      venue.categories_Automotive Shop   0.2
#
#
# Northwood Park, York University
#                                  venue  freq
# 0      venue.categories_Breakfast Spot   0.2
# 1         venue.categories_Coffee Shop   0.2
# 2      venue.categories_Clothing Store   0.2
# 3        venue.categories_Climbing Gym   0.2
# 4  venue.categories_Athletics & Sports   0.2
#
#
# Not assigned
#                                   venue  freq
# 0      venue.categories_Bubble Tea Shop   0.2
# 1          venue.categories_Coffee Shop   0.2
# 2         venue.categories_Burger Joint   0.2
# 3        venue.categories_Burrito Place   0.2
# 4  venue.categories_Arts & Crafts Store   0.2
#
#
# Parkdale, Roncesvalles
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1               venue.categories_Bakery   0.2
# 2  venue.categories_American Restaurant   0.2
# 3                  venue.categories_Bar   0.2
# 4              venue.categories_Brewery   0.2
#
#
# Parkwoods
#                                    venue  freq
# 0           venue.categories_Event Space   0.2
# 1          venue.categories_Burger Joint   0.2
# 2                  venue.categories_Café   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4            venue.categories_Bagel Shop   0.2
#
#
# Rosedale
#                                  venue  freq
# 0           venue.categories_BBQ Joint   0.2
# 1         venue.categories_Coffee Shop   0.2
# 2  venue.categories_Athletics & Sports   0.2
# 3      venue.categories_Breakfast Spot   0.2
# 4                 venue.categories_Bar   0.2
#
#
# Roselawn
#                              venue  freq
# 0       venue.categories_Bookstore   0.2
# 1    venue.categories_Burger Joint   0.2
# 2  venue.categories_Baseball Field   0.2
# 3          venue.categories_Bakery   0.2
# 4  venue.categories_Breakfast Spot   0.2
#
#
# Rouge, Malvern
#                                    venue  freq
# 0          venue.categories_Burger Joint   0.2
# 1            venue.categories_Campground   0.2
# 2    venue.categories_Athletics & Sports   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Runnymede, Swansea
#                             venue  freq
# 0      venue.categories_Bookstore   0.2
# 1    venue.categories_Coffee Shop   0.2
# 2  venue.categories_Burrito Place   0.2
# 3           venue.categories_Café   0.2
# 4         venue.categories_Bakery   0.2
#
#
# Ryerson, Garden District
#                                   venue  freq
# 0  venue.categories_American Restaurant   0.2
# 1         venue.categories_Burger Joint   0.2
# 2          venue.categories_Art Gallery   0.2
# 3        venue.categories_Burrito Place   0.2
# 4             venue.categories_Beer Bar   0.2
#
#
# Scarborough Village
#                                venue  freq
# 0         venue.categories_Bookstore   0.2
# 1            venue.categories_Bistro   0.2
# 2      venue.categories_Burger Joint   0.2
# 3             venue.categories_Beach   0.2
# 4  venue.categories_Asian Restaurant   0.2
#
#
# Silver Hills, York Mills
#                                    venue  freq
# 0           venue.categories_Event Space   0.2
# 1        venue.categories_Cosmetics Shop   0.2
# 2  venue.categories_Caribbean Restaurant   0.2
# 3            venue.categories_Bagel Shop   0.2
# 4        venue.categories_Breakfast Spot   0.2
#
#
# St. James Town
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1  venue.categories_American Restaurant   0.2
# 2          venue.categories_Coffee Shop   0.2
# 3                 venue.categories_Café   0.2
# 4               venue.categories_Church   0.2
#
#
# Stn A PO Boxes 25 The Esplanade
#                                  venue  freq
# 0         venue.categories_Cheese Shop   0.2
# 1  venue.categories_Belgian Restaurant   0.2
# 2            venue.categories_Beer Bar   0.2
# 3                venue.categories_Café   0.2
# 4              venue.categories_Bakery   0.2
#
#
# Studio District
#                           venue  freq
# 0  venue.categories_Cheese Shop   0.2
# 1    venue.categories_Bookstore   0.2
# 2         venue.categories_Café   0.2
# 3          venue.categories_Bar   0.2
# 4       venue.categories_Bakery   0.2
#
#
# The Annex, North Midtown, Yorkville
#                                   venue  freq
# 0            venue.categories_BBQ Joint   0.2
# 1            venue.categories_Bookstore   0.2
# 2  venue.categories_American Restaurant   0.2
# 3         venue.categories_Burger Joint   0.2
# 4                 venue.categories_Café   0.2
#
#
# The Beaches
#                              venue  freq
# 0      venue.categories_Bagel Shop   0.2
# 1       venue.categories_BBQ Joint   0.2
# 2           venue.categories_Beach   0.2
# 3          venue.categories_Bakery   0.2
# 4  venue.categories_Breakfast Spot   0.2
#
#
# The Beaches West, India Bazaar
#                                venue  freq
# 0           venue.categories_Brewery   0.2
# 1      venue.categories_Burger Joint   0.2
# 2     venue.categories_Burrito Place   0.2
# 3             venue.categories_Beach   0.2
# 4  venue.categories_Asian Restaurant   0.2
#
#
# The Danforth West, Riverdale
#                         venue  freq
# 0  venue.categories_BBQ Joint   0.2
# 1     venue.categories_Bakery   0.2
# 2  venue.categories_Bookstore   0.2
# 3       venue.categories_Café   0.2
# 4    venue.categories_Brewery   0.2
#
#
# The Junction North, Runnymede
#                                   venue  freq
# 0               venue.categories_Bakery   0.2
# 1  venue.categories_Arts & Crafts Store   0.2
# 2   venue.categories_Athletics & Sports   0.2
# 3              venue.categories_Brewery   0.2
# 4                  venue.categories_Bar   0.2
#
#
# The Kingsway, Montgomery Road, Old Mill North
#                              venue  freq
# 0  venue.categories_Breakfast Spot   0.2
# 1     venue.categories_Coffee Shop   0.2
# 2    venue.categories_Burger Joint   0.2
# 3            venue.categories_Café   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Thorncliffe Park
#                                 venue  freq
# 0          venue.categories_BBQ Joint   0.2
# 1             venue.categories_Bakery   0.2
# 2  venue.categories_Afghan Restaurant   0.2
# 3    venue.categories_Auto Dealership   0.2
# 4            venue.categories_Brewery   0.2
#
#
# Upper Rouge
#                                    venue  freq
# 0    venue.categories_Chinese Restaurant   0.2
# 1          venue.categories_Burger Joint   0.2
# 2    venue.categories_Athletics & Sports   0.2
# 3  venue.categories_Caribbean Restaurant   0.2
# 4                venue.categories_Bakery   0.2
#
#
# Victoria Village
#                              venue  freq
# 0         venue.categories_Brewery   0.2
# 1  venue.categories_Cosmetics Shop   0.2
# 2  venue.categories_Clothing Store   0.2
# 3            venue.categories_Café   0.2
# 4          venue.categories_Bakery   0.2
#
#
# Westmount
#                                  venue  freq
# 0  venue.categories_Chinese Restaurant   0.2
# 1        venue.categories_Burger Joint   0.2
# 2                venue.categories_Café   0.2
# 3    venue.categories_Asian Restaurant   0.2
# 4              venue.categories_Bakery   0.2
#
#
# Weston
#                                venue  freq
# 0          venue.categories_Boutique   0.2
# 1  venue.categories_Asian Restaurant   0.2
# 2              venue.categories_Café   0.2
# 3            venue.categories_Bakery   0.2
# 4           venue.categories_Brewery   0.2
#
#
# Willowdale South
#                               venue  freq
# 0  venue.categories_Bubble Tea Shop   0.2
# 1      venue.categories_Coffee Shop   0.2
# 2    venue.categories_Burrito Place   0.2
# 3             venue.categories_Café   0.2
# 4           venue.categories_Bakery   0.2
#
#
# Willowdale West
#                                venue  freq
# 0         venue.categories_Bookstore   0.2
# 1   venue.categories_Bubble Tea Shop   0.2
# 2  venue.categories_Asian Restaurant   0.2
# 3   venue.categories_Auto Dealership   0.2
# 4        venue.categories_Bagel Shop   0.2
#
#
# Woburn
#                                    venue  freq
# 0    venue.categories_Chinese Restaurant   0.2
# 1           venue.categories_Coffee Shop   0.2
# 2          venue.categories_Burger Joint   0.2
# 3    venue.categories_Athletics & Sports   0.2
# 4  venue.categories_Caribbean Restaurant   0.2
#
#
# Woodbine Gardens, Parkview Hill
#                                 venue  freq
# 0            venue.categories_Brewery   0.2
# 1  venue.categories_Afghan Restaurant   0.2
# 2                venue.categories_Bar   0.2
# 3             venue.categories_Bakery   0.2
# 4     venue.categories_Breakfast Spot   0.2
#
#
# Woodbine Heights
#                                   venue  freq
# 0       venue.categories_Breakfast Spot   0.2
# 1               venue.categories_Bakery   0.2
# 2  venue.categories_American Restaurant   0.2
# 3             venue.categories_Beer Bar   0.2
# 4                  venue.categories_Bar   0.2
#
#
# York Mills West
#                              venue  freq
# 0  venue.categories_Cosmetics Shop   0.2
# 1     venue.categories_Coffee Shop   0.2
# 2    venue.categories_Burger Joint   0.2
# 3            venue.categories_Café   0.2
# 4          venue.categories_Bakery   0.2

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
